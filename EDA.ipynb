# %%
import pandas as pd 
import numpy as np

# %%
import pandas as pd

single_argo = pd.read_csv('3901161_1386_EasyTSLite.csv', comment='#')

# %%
single_argo
# Out:
#      pressure (decibar)  temperature (degree_celsius)  \
# 0                   2.0                        27.643
# 1                   5.0                        27.636
# 2                  10.0                        27.528
# 3                  15.0                        27.435
# 4                  20.0                        27.424
# ..                  ...                           ...
# 102              5200.0                           NaN
# 103              5400.0                           NaN
# 104              5600.0                           NaN
# 105              5800.0                           NaN
# 106              6000.0                           NaN
#
#      salinity (dimensionless)  pressure_error (decibar)  \
# 0                      34.076                      2.42
# 1                      34.077                      2.42
# 2                      34.076                      2.42
# 3                      34.071                      2.42
# ...
